# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_netflix.csv")

# %%
df.head()
df.info()
df.describe(include="all")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   str
#  1   type          8790 non-null   str
#  2   title         8790 non-null   str
#  3   director      8790 non-null   str
#  4   country       8790 non-null   str
#  5   date_added    8790 non-null   str
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   str
#  8   duration      8790 non-null   str
#  9   listed_in     8790 non-null   str
# dtypes: int64(1), str(9)
# memory usage: 686.8 KB
#        show_id   type  title   director        country date_added  \
# count     8790   8790   8790       8790           8790       8790
# unique    8790      2   8787       4528             86       1713
# top         s1  Movie  9-Feb  Not Given  United States   1/1/2020
# freq         1   6126      2       2588           3240        110
# ...

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
df["country"].value_counts().head(10)
# Out:
# country
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
# Canada             271
# Japan              259
# South Korea        214
# France             213
# Spain              182
# Name: count, dtype: int64

# %%
df["rating"].value_counts()
# Out:
# rating
# TV-MA       3205
# TV-14       2157
# TV-PG        861
# R            799
# PG-13        490
# TV-Y7        333
# TV-Y         306
# PG           287
# TV-G         220
# NR            79
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# Name: count, dtype: int64

# %%
genres = df["listed_in"].str.split(", ").explode()
genres.value_counts().head(10)
# Out:
# listed_in
# International Movies        2752
# Dramas                      2426
# Comedies                    1674
# International TV Shows      1349
# Documentaries                869
# Action & Adventure           859
# TV Dramas                    762
# Independent Movies           756
# Children & Family Movies     641
# Romantic Movies              616
# Name: count, dtype: int64

# %%
df["release_year"].value_counts().sort_index()
# Out:
# release_year
# 1925       1
# 1942       2
# 1943       3
# 1944       3
# 1945       4
#         ...
# 2017    1030
# 2018    1146
# 2019    1030
# 2020     953
# 2021     592
# Name: count, Length: 74, dtype: int64

# %%
sns.countplot(data=df, x="type")
plt.title("Movies vs TV Shows")
plt.show()

# %%
top10 = df["country"].value_counts().head(10)

sns.barplot(x=top10.values, y=top10.index)

plt.title("Top 10 Countries")
plt.show()

# %%
trend = df["release_year"].value_counts().sort_index()

sns.lineplot(
    x=trend.index,
    y=trend.values,
    marker="o"
)

plt.title("Content Release Trend")
plt.show()

# %%
sns.countplot(
    data=df,
    y="rating",
    order=df["rating"].value_counts().index
)

plt.title("Content Ratings")
plt.show()

# %%
genres = df["listed_in"].str.split(", ").explode()

top_genres = genres.value_counts().head(10)

sns.barplot(
    x=top_genres.values,
    y=top_genres.index
)

plt.title("Top 10 Genres")
plt.show()

# %% [markdown]
# # Netflix Business Intelligence Report
#
# ## Objective
# To analyze Netflix content using Python and derive business insights through exploratory data analysis and visualizations.
#
# ## Analysis Performed
# • Data Cleaning
# • Content Type Analysis
# • Country-wise Analysis
# • Release Year Trend
# • Rating Analysis
# • Genre Analysis
#
# ## Key Findings
# • Movies dominate the catalog.
# • United States leads in content production.
# • Content production increased significantly after 2015.
# • TV-MA is the most frequent rating.
# • Drama and International Movies are highly represented.
#
# ## Business Recommendations
# • Continue investing in regional content.
# • Expand family-friendly programming in underrepresented markets.
# • Monitor genre trends to optimize future content acquisition.
